# %%
#파이썬으로 구현하는 블랙-숄즈 모형
from scipy import stats #사이파이(Scipy)는 과학, 통계 관련 기능 제공, 표준정규분포를 구현하는데 이용
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#잔존만기 계산
def time_to_maturity(t0,T,y=252):
    t0 = pd.to_datetime(t0)
    T=pd.to_datetime(T)
    
    return (np.busday_count(t0.date(),T.date()) / y) #busday_count함수의 인자에는 .date()를 붙여야 함

time_to_maturity('2018-8-1', '2018-12-14')
# Out:
# 0.38492063492063494

# %%
#블랙-숄즈 방정식을 이용한 콜옵션 가격 구하기
def call_price(S, K, ttm, r, sigma):
    d1 = (np.log(S/K) + (r + sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
    d2 = (np.log(S/K) + (r - sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
    #d2 = d1 - sigma * sqrt(ttm)도 같은 수식
    val = (S * stats.norm.cdf(d1, 0.0, 1.0) ) - K * np.exp(-r * ttm) * stats.norm.cdf(d2, 0.0, 1.0)
    return val

# %%
ttm = time_to_maturity('2018-9-1', '2018-12-14')
r = 0.025
sigma = 0.15

# %%
call_price(350, 350, ttm, r, sigma)
# Out:
# 12.631163296464337

# %%
#기초자산 및 행사가격 변화에 따른 콜옵션가격 변화
call_space = dict()
S = np.arange(200,400,10) #기초자산 가격이 200~390까지 10만큼씩 증가하는 상황
for s in S:
    call_space[s] = call_price(s, 300, ttm, r, sigma)
call_space
# Out:
# {200: 1.8229865417689555e-06,
#  210: 3.724332522961858e-05,
#  220: 0.0004848219345010875,
#  230: 0.0042640947867984835,
#  240: 0.02665577204552605,
#  250: 0.12380641693770844,
#  260: 0.44438348272742445,
#  270: 1.2768817597123174,
#  280: 3.032518983510599,
#  290: 6.129007185638784,
#  300: 10.826711396969444,
#  310: 17.12542427826159,
#  320: 24.78644022660987,
#  330: 33.44839060274677,
#  340: 42.75369718631481,
#  350: 52.42501910316514,
#  360: 62.28260578675133,
#  370: 72.22579369772768,
#  380: 82.20481472928111,
#  390: 92.19760562684911}

# %%
#기초자산도 변하고 행사가격도 변하는 경우
call_space = dict()
K = np.arange(250,350,10)
S = np.arange(200,400,10)
for k in K:
    single_space = dict()
    for s in S:
        single_space[s] = call_price(s,k,ttm,r,sigma)
    call_space[k] = pd.Series(single_space)
call_space
# Out:
# {250: 200      0.022213
#  210      0.135833
#  220      0.579058
#  230      1.825802
#  240      4.488751
#  250      9.022259
#  260     15.466104
#  270     23.460286
#  280     32.478630
#  290     42.059513
#  300     51.902171
#  310     61.849766
#  320     71.834137
#  330     81.829925
#  340     91.828891
#  350    101.828657
#  360    111.828609
#  370    121.828599
#  380    131.828597
#  390    141.828597
#  dtype: float64,
#  260: 200      0.004304
#  210      0.033756
#  220      0.180484
#  230      0.697475
#  240      2.051631
#  250      4.811862
#  260      9.383150
#  270     15.793869
#  280     23.714323
#  290     32.658000
#  300     42.185391
#  310     51.997862
#  320     61.931345
#  330     71.910080
#  340     81.903903
#  350     91.902260
#  360    101.901857
#  370    111.901765
#  380    121.901746
#  390    131.901742
#  dtype: float64,
#  270: 200      0.000730
#  210      0.007326
#  220      0.049127
#  230      0.233416
#  240      0.826890
#  250      2.285869
#  260      5.137706
#  270      9.744040
#  280     16.123890
#  290     23.974387
#  300     32.844968
#  310     42.317738
#  320     52.097756
#  330     62.015143
#  340     71.987012
#  350     81.978262
#  360     91.975760
#  370    101.975097
#  380    111.974933
#  390    121.974895
#  dtype: float64,
#  280: 200      0.000110
#  210      0.001405
#  220      0.011791
#  230      0.068909
#  240      0.294930
#  250      0.966895
#  260      2.527836
#  270      5.466003
#  280     10.104931
#  290     16.455946
#  300     24.240029
#  310     33.039230
#  320     42.456586
#  330     52.202111
#  340     62.101442
#  350     72.065133
#  360     82.053114
#  370     92.049440
#  380    102.048396
#  390    112.048119
#  dtype: float64,
#  290: 200      0.000015
#  210      0.000241
#  220      0.002521
#  230      0.018096
#  240      0.093641
#  250      0.365220
#  260      1.117045
#  270      2.776908
#  280      5.796508
#  290     10.465821
#  300     16.789847
#  310     24.510839
#  320     33.240475
#  330     42.601923
#  340     52.311140
#  350     62.190512
#  360     72.144655
#  370     82.128585
#  380     92.123364
#  390    102.121782
#  dtype: float64,
#  300: 200     0.000002
#  210     0.000037
#  220     0.000485
#  230     0.004264
#  240     0.026656
#  250     0.123806
#  260     0.444383
#  270     1.276882
#  280     3.032519
#  290     6.129007
#  300    10.826711
#  310    17.125424
#  320    24.786440
#  330    33.448391
#  340    42.753697
#  350    52.425019
#  360    62.282606
#  370    72.225794
#  380    82.204815
#  390    92.197606
#  dtype: float64,
#  310: 200    2.051670e-07
#  210    5.257695e-06
#  220    8.468891e-05
#  230    9.096275e-04
#  240    6.855433e-03
#  250    3.789918e-02
#  260    1.598281e-01
#  270    5.324374e-01
#  280    1.445938e+00
#  290    3.294155e+00
#  300    6.463313e+00
#  310    1.118760e+01
#  320    1.746253e+01
#  330    2.506649e+01
#  340    3.366267e+01
#  350    4.291182e+01
#  360    5.254388e+01
#  370    6.237796e+01
#  380    7.230876e+01
#  390    8.228195e+01
#  dtype: float64,
#  320: 200    2.137537e-08
#  210    6.833560e-07
#  220    1.355684e-05
#  230    1.771610e-04
#  240    1.605359e-03
#  250    1.054734e-02
#  260    5.224992e-02
#  270    2.020632e-01
#  280    6.293300e-01
#  290    1.623750e+00
#  300    3.561349e+00
#  310    6.799261e+00
#  320    1.154849e+01
#  330    1.780103e+01
#  340    2.535067e+01
#  350    3.388300e+01
#  360    4.307620e+01
#  370    5.266783e+01
#  380    6.247677e+01
#  390    7.239377e+01
#  dtype: float64,
#  330: 200    2.078843e-09
#  210    8.245959e-08
#  220    2.005285e-06
#  230    3.175612e-05
#  240    3.449005e-04
#  250    2.687044e-03
#  260    1.561818e-02
#  270    7.011863e-02
#  280    2.508041e-01
#  290    7.349539e-01
#  300    1.809864e+00
#  310    3.833676e+00
#  320    7.136706e+00
#  330    1.190938e+01
#  340    1.814080e+01
#  350    2.563869e+01
#  360    3.410909e+01
#  370    4.324668e+01
#  380    5.279694e+01
#  390    6.257923e+01
#  dtype: float64,
#  340: 200    1.901492e-10
#  210    9.308611e-09
#  220    2.761759e-07
#  230    5.278307e-06
#  240    6.847559e-05
#  250    6.309106e-04
#  260    4.294832e-03
#  270    2.236542e-02
#  280    9.189374e-02
#  290    3.062803e-01
#  300    8.491565e-01
#  310    2.003839e+00
#  320    4.110749e+00
#  330    7.475517e+00
#  340    1.227027e+01
#  350    1.848175e+01
#  360    2.593028e+01
#  370    3.434066e+01
#  380    4.342313e+01
#  390    5.293123e+01
#  dtype: float64}

# %%
df_call_space = pd.DataFrame(call_space)
df_call_space
# Out:
#             250         260         270         280         290        300  \
# 200    0.022213    0.004304    0.000730    0.000110    0.000015   0.000002
# 210    0.135833    0.033756    0.007326    0.001405    0.000241   0.000037
# 220    0.579058    0.180484    0.049127    0.011791    0.002521   0.000485
# 230    1.825802    0.697475    0.233416    0.068909    0.018096   0.004264
# 240    4.488751    2.051631    0.826890    0.294930    0.093641   0.026656
# 250    9.022259    4.811862    2.285869    0.966895    0.365220   0.123806
# 260   15.466104    9.383150    5.137706    2.527836    1.117045   0.444383
# 270   23.460286   15.793869    9.744040    5.466003    2.776908   1.276882
# 280   32.478630   23.714323   16.123890   10.104931    5.796508   3.032519
# 290   42.059513   32.658000   23.974387   16.455946   10.465821   6.129007
# 300   51.902171   42.185391   32.844968   24.240029   16.789847  10.826711
# 310   61.849766   51.997862   42.317738   33.039230   24.510839  17.125424
# 320   71.834137   61.931345   52.097756   42.456586   33.240475  24.786440
# 330   81.829925   71.910080   62.015143   52.202111   42.601923  33.448391
# 340   91.828891   81.903903   71.987012   62.101442   52.311140  42.753697
# 350  101.828657   91.902260   81.978262   72.065133   62.190512  52.425019
# 360  111.828609  101.901857   91.975760   82.053114   72.144655  62.282606
# 370  121.828599  111.901765  101.975097   92.049440   82.128585  72.225794
# 380  131.828597  121.901746  111.974933  102.048396   92.123364  82.204815
# 390  141.828597  131.901742  121.974895  112.048119  102.121782  92.197606
#
#               310           320           330           340
# 200  2.051670e-07  2.137537e-08  2.078843e-09  1.901492e-10
# 210  5.257695e-06  6.833560e-07  8.245959e-08  9.308611e-09
# 220  8.468891e-05  1.355684e-05  2.005285e-06  2.761759e-07
# 230  9.096275e-04  1.771610e-04  3.175612e-05  5.278307e-06
# 240  6.855433e-03  1.605359e-03  3.449005e-04  6.847559e-05
# 250  3.789918e-02  1.054734e-02  2.687044e-03  6.309106e-04
# 260  1.598281e-01  5.224992e-02  1.561818e-02  4.294832e-03
# 270  5.324374e-01  2.020632e-01  7.011863e-02  2.236542e-02
# 280  1.445938e+00  6.293300e-01  2.508041e-01  9.189374e-02
# 290  3.294155e+00  1.623750e+00  7.349539e-01  3.062803e-01
# 300  6.463313e+00  3.561349e+00  1.809864e+00  8.491565e-01
# 310  1.118760e+01  6.799261e+00  3.833676e+00  2.003839e+00
# 320  1.746253e+01  1.154849e+01  7.136706e+00  4.110749e+00
# 330  2.506649e+01  1.780103e+01  1.190938e+01  7.475517e+00
# 340  3.366267e+01  2.535067e+01  1.814080e+01  1.227027e+01
# 350  4.291182e+01  3.388300e+01  2.563869e+01  1.848175e+01
# 360  5.254388e+01  4.307620e+01  3.410909e+01  2.593028e+01
# 370  6.237796e+01  5.266783e+01  4.324668e+01  3.434066e+01
# 380  7.230876e+01  6.247677e+01  5.279694e+01  4.342313e+01
# 390  8.228195e+01  7.239377e+01  6.257923e+01  5.293123e+01

# %%
#콜옵션가격 그래프 그리기
#행사가별 옵션가격 그래프
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 12
plt.rcParams['axes.unicode_minus'] = False

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(df_call_space[290], label = 'k=290')
ax.plot(df_call_space[300], label = 'k=300')
ax.plot(df_call_space[310], label = 'k=310')
ax.set_xlabel('기초자산가격(Underlying)')
ax.set_ylabel('콜옵션가격(Call price)')
ax.set_title ('행사가별 옵션가격')
ax.legend(loc='best')

# %%
#콜옵션가격 곡면
S = np.arange(200,400,10)
call_price(S, 300, ttm, r, sigma) #for문을 이용하는 대신 구간으로 한꺼번에 설정
# Out:
# array([1.82298654e-06, 3.72433252e-05, 4.84821935e-04, 4.26409479e-03,
#        2.66557720e-02, 1.23806417e-01, 4.44383483e-01, 1.27688176e+00,
#        3.03251898e+00, 6.12900719e+00, 1.08267114e+01, 1.71254243e+01,
#        2.47864402e+01, 3.34483906e+01, 4.27536972e+01, 5.24250191e+01,
#        6.22826058e+01, 7.22257937e+01, 8.22048147e+01, 9.21976056e+01])

# %%
K = np.arange(250,350,10)
S = np.arange(200,400,10)
call_price(S, K, ttm, r, sigma) #에러 발생 -> 원소의 개수가 다름
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-2afdd8dfc7a1> in <module>
#       1 K = np.arange(250,350,10)
#       2 S = np.arange(200,400,10)
# ----> 3 call_price(S, K, ttm, r, sigma) #에러 발생 -> 원소의 개수가 다름
#
# <ipython-input-12-a2c5bdad1e8d> in call_price(S, K, ttm, r, sigma)
#       1 #블랙-숄즈 방정식을 이용한 콜옵션 가격 구하기
#       2 def call_price(S, K, ttm, r, sigma):
# ----> 3     d1 = (np.log(S/K) + (r + sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
#       4     d2 = (np.log(S/K) + (r - sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
#       5     #d2 = d1 - sigma * sqrt(ttm)도 같은 수식
#
# ValueError: operands could not be broadcast together with shapes (20,) (10,)

# %%
K = np.arange(250,350,5)
S = np.arange(200,400,10)
call_price(S,K,ttm,r,sigma)
# Out:
# array([2.22131434e-02, 6.89203034e-02, 1.80483718e-01, 4.10056194e-01,
#        8.26890264e-01, 1.50822008e+00, 2.52783587e+00, 3.94495525e+00,
#        5.79650803e+00, 8.09429432e+00, 1.08267114e+01, 1.39636109e+01,
#        1.74625277e+01, 2.12748025e+01, 2.53506674e+01, 2.96429042e+01,
#        3.41090900e+01, 3.87126629e+01, 4.34231292e+01, 4.82157178e+01])

# %%
#오류가 발생 X -> 이 데이터로 3D 데이터 그리기
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
K = np.arange(250,350,5)
S = np.arange(200,400,10)

Z = call_price(S,K,ttm,r,sigma)

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

surf = ax.plot_surface(S,K,Z, cmap = cm.summer,
                       linewidth = 1 , antialiased = True, alpha = 0.8)

ax.set_xlabel('기초자산(Underlying)')
ax.set_ylabel('행사가격(Strike)')
ax.set_zlabel('콜옵션가격(Call Price)')
ax.set_title('콜옵션 가격 곡면을 그리고 싶었으나...')

fig.colorbar(surf, shrink=0.5, aspect=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-f76816ed1212> in <module>
#      11
#      12 surf = ax.plot_surface(S,K,Z, cmap = cm.summer,
# ---> 13                        linewidth = 1 , antialiased = True, alpha = 0.8)
#      14
#      15 ax.set_xlabel('기초자산(Underlying)')
#
# ~\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1580
#    1581         if Z.ndim != 2:
# -> 1582             raise ValueError("Argument Z must be 2-dimensional.")
#    1583         if np.any(np.isnan(Z)):
#    1584             cbook._warn_external(
#
# ValueError: Argument Z must be 2-dimensional.

# %%
#K와 S값을 배트릭스로 입력하지 않아서 평면을 그리지 못함
K = np.arange(250,350,5)
S = np.arange(200,400,10)

Z = call_price(S,K,ttm,r,sigma)

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

surf = ax.plot(S,K,Z,linewidth = 5 , antialiased = True, alpha = 0.8) #평면을 그리도록 수정

ax.set_xlabel('기초자산(Underlying)')
ax.set_ylabel('행사가격(Strike)')
ax.set_zlabel('콜옵션가격(Call Price)')
ax.set_title('콜옵션 가격 선분밖에 못그림')
# Out:
# Text(0.5, 0.92, '콜옵션 가격 선분밖에 못그림')

# %%
#매트릭스를 이용, 3차원으로 그려보면
K = np.arange(250,350,5)
S = np.arange(200,400,10)
K,S = np.meshgrid(K,S) #매트릭스 만들기
Z = call_price(S,K,ttm,r,sigma)

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

surf = ax.plot_surface(S,K,Z, cmap = cm.summer,
                       linewidth = 1 , antialiased = True, alpha = 0.8)

ax.set_xlabel('기초자산(Underlying)')
ax.set_ylabel('행사가격(Strike)')
ax.set_zlabel('콜옵션가격(Call Price)')
ax.set_title('콜옵션 가격 곡면')

fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
#풋옵션 가격 곡면 그리기
def put_price(S,K,ttm,r,sigma):
    d1 = (np.log(S/K) + (r + sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
    d2 = (np.log(S/K) + (r - sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
    val = K * np.exp(-r * ttm) * stats.norm.cdf(-d2, 0.0, 1.0) - (S * stats.norm.cdf(-d1, 0.0, 1.0))
    return val

# %%
#풋옵션 가격곡면을 그려보면
K = np.arange(250,350,5)
S = np.arange(200,400,10)
K, S = np.meshgrid(K, S)
Z = put_price(S, K , ttm, r, sigma)

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

surf = ax.plot_surface(S, K, Z, cmap = cm.winter, linewidth = 1, antialiased = True, alpha = 0.8)

ax.set_xlabel('기초자산(Underlying)')
ax.set_ylabel('행사가격(Strike)')
ax.set_zlabel('풋옵션가격(Put Price)')
ax.set_title('풋옵션 가격 곡면')

fig.colorbar(surf, shrink = 0.5, aspect =5)

# %%
# 옵션 그릭스 그래프 그리기
# 콜옵션 델타 그래프
def call_delta(S, K , ttm, r, sigma):
    d1 = (np.log(S/K) + (r + sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
    val = stats.norm.cdf(d1, 0.0, 1.0)
    return val

# %%
K = np.arange(300,350,5)
S = np.arange(200,400,10)
K, S = np.meshgrid(K,S)
Z = call_delta(S, K, 0.38, 0.02, 0.30)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(S, K, Z, cmap = cm.coolwarm, linewidth = 1, antialiased = True, alpha = 0.8)

ax.set_xlabel('기초자산(Underlying)')
ax.set_ylabel('행사가격(Strike)')
ax.set_zlabel('델타(Delta)')
ax.set_title('델타곡면')

fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
#감마 그래프
#N'(x) 함수 정의
def ndx(x):
    return (np.exp(-1 * x**2 * 0.5) / np.sqrt(2 * np.pi) )

# %%
def gamma(S,K,ttm,r,sigma):
    d1 = ( np.log(S/K) + (r + sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
    val = (ndx(d1)) / (S * sigma * np.sqrt(ttm))
    return val

# %%
K = np.arange(300,305)
S = np.arange(200,400,10)
K, S = np.meshgrid(K,S)
Z = gamma(S, K, 0.38, 0.02, 0.30)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(S, K, Z, cmap = cm.summer, linewidth = 1, antialiased = True, alpha = 0.8)

ax.set_xlabel('기초자산(Underlying)')
ax.set_ylabel('행사가격(Strike)')
ax.set_zlabel('감마(Gamma)')
ax.set_title('감마곡면')

fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
#콜옵션 세타 그래프
def call_theta(S, K, ttm, r, sigma):
    d1 = (np.log(S/K) + (r + sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
    d2 = (np.log(S/K) + (r - sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
    val = -1 * ( (S*ndx(d1) * sigma) / (2*np.sqrt(ttm)) ) - r* K* np.exp(-r*ttm) * stats.norm.cdf(d2, 0.0, 1.0)
    return val

# %%
T = np.arange(1.0, 0.0, -0.01)
S = np.arange(350,355)
T, S = np.meshgrid(T,S)
Z = call_theta(S, 350, T, 0.02, .30)

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

surf = ax.plot_surface(T,S,Z, cmap = cm.summer, linewidth = 1, antialiased = True, alpha = 0.8)

ax.set_xlabel('잔존만기(Time to Maturity)')
ax.set_ylabel('기초자산(Underlying)')
ax.set_zlabel('세타(Theta)')
ax.invert_xaxis() #X축을 1부터 0의 순서로 거꾸로 출력 -> 잔존만기가 0으로 다가갈 수록 세타가 급격히 하락하는 것 확인
ax.set_title('세타곡면')

fig.colorbar(surf, shrink=0.5, aspect = 5)

# %%
#베가 그래프
def vega(S, K, ttm, r, sigma):
    d1 = (np.log(S/K) + (r + sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
    d2 = (np.log(S/K) + (r - sigma**2 * 0.5) * ttm) / (sigma * np.sqrt(ttm))
    val = (S* np.sqrt(ttm) * ndx(d1) )
    return val

# %%
V = np.arange(0.05, 0.95, 0.01)
S = np.arange(350, 352)
V, S = np.meshgrid(V,S)
Z = vega(S, 350, 0.38, 0.02, V)

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

surf = ax.plot_surface(V, S, Z, cmap = cm.spring, linewidth = 1, antialiased = True, alpha = 0.8)

ax.set_xlabel('변동성(Volatility)')
ax.set_ylabel('기초자산(Underlying)')
ax.set_zlabel('베가(Vega)')
ax.set_title('베가 곡면')

fig.colorbar(surf, shrink = 0.5, aspect = 5)
